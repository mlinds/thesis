# %%
import numpy as np
from netCDF4 import Dataset

# %cd ..
# Out:
# /mnt/c/Users/maxli/OneDrive - Van Oord/Documents/thesis

# %%
ncfile = "../data/test_sites/florida_keys/ATL09/processed_ATL09_20181017081233_02860101_005_01.nc"
ds = Dataset(ncfile)
groups = ds.groups
grouplist = [profname for profname in groups.keys() if profname.startswith("prof")]

# %%
xrlist = []
for groupname in grouplist:
    for subgroup in groups[groupname].groups.keys():
        xrds = Dataset(ncfile).groups[groupname].groups[subgroup]
        xrlist.append(xrds)

# %%
for group in xrlist:
    for variable in group.variables.keys():
        name = group.variables[variable].name
        type_ = group.variables[variable].dtype
        array = group.variables[variable][:]
    columndtype = np.dtype([(name, type_)])

    columnstarray = np.array(array, dtype=columndtype)
    print(columnstarray.shape)
# Out:
# (3,)
# (63,)
# (3,)
# (63,)
# (3,)

# %%
xrlist[4]
# Out:
# <xarray.Dataset>
# Dimensions:     (delta_time: 3)
# Coordinates:
#   * delta_time  (delta_time) datetime64[ns] 2018-10-17T08:53:08.058631888 ......
# Data variables:
#     met_ps      (delta_time) float32 ...
#     met_slp     (delta_time) float32 ...
#     met_u2m     (delta_time) float32 ...
#     met_v2m     (delta_time) float32 ...
#     profile     <U9 'profile_3'
# Attributes:
#     Description:  Contains parameters related to atmosphere characteristic at...
#     data_rate:    Data in this group is stored at a 1hz (1 per second) rate.

# %%
xr.concat(xrlist, dim="delta_time", data_vars="minimal")
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 xr.concat(xrlist,dim='delta_time',data_vars='minimal')
#
# File ~/mambaforge/envs/thesis_env/lib/python3.9/site-packages/xarray/core/concat.py:238, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     233 else:
#     234     raise TypeError(
#     235         "can only concatenate xarray Dataset and DataArray "
#     236         f"objects, got {type(first_obj)}"
#     237     )
# --> 238 return f(
#     239     objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs
#     240 )
#
# File ~/mambaforge/envs/thesis_env/lib/python3.9/site-packages/xarray/core/concat.py:478, in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
# ...

# %%
xrlist[-1]
# Out:
# <xarray.Dataset>
# Dimensions:     (delta_time: 3)
# Coordinates:
#   * delta_time  (delta_time) datetime64[ns] 2018-10-17T08:53:08.058631888 ......
# Data variables:
#     met_ps      (delta_time) float32 1.016e+05 1.016e+05 1.016e+05
#     met_slp     (delta_time) float32 1.016e+05 1.016e+05 1.016e+05
#     met_u2m     (delta_time) float32 -7.347 -7.347 -7.347
#     met_v2m     (delta_time) float32 1.245 1.245 1.245
# Attributes:
#     Description:  Contains parameters related to atmosphere characteristic at...
#     data_rate:    Data in this group is stored at a 1hz (1 per second) rate.
