# %%
# %cd ..
from atl_module import GebcoUpscaler

site = GebcoUpscaler("../data/test_sites/oahu2/", "oahu2")
# Out:
# /mnt/c/Users/XCB/OneDrive - Van Oord/Documents/thesis/code

# %%
fig = site.plot_site()
# Out:
# plotting tracklines
# finished plotting tracklines
# finished plotting basemap
# plotting photon map
# finished plotting photons
# finished adding basemap

# %%
fig.get_size_inches() * 1.5
# Out:
# array([9., 6.])

# %%
fig.set_size_inches(fig.get_size_inches() * 2)

# %%
fig.set_tight_layout(False)
fig

# %%
fig.set_tight_layout(True)
fig
